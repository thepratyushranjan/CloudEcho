# %%
import sys
import os
import requests
import json
import itertools
import ast
from typing import Dict, Any, List, Tuple, Union
from datetime import datetime, UTC

# %%
resourceJsonString = {
    "cloud_account_id": "9d3a6221-2d42-40ba-8aad-1f50c0cb4bdf",
    "cloud_resource_id": "i-0fbe5281266b3022c",
    "applied_rules": [
        {
            "id": "8aebbe1b-6b62-41ab-a33d-2bba0d763cba",
            "name": "Rule for API-KYC_1747387550",
            "pool_id": "6e57e642-0c77-4829-940e-36dc692255c2"
        }
    ],
    "created_at": 1747387567,
    "deleted_at": 0,
    "employee_id": "a1aeb309-c565-4cbd-a25e-8fe25f3328de",
    "first_seen": 1742169600,
    "last_seen": 1752224434,
    "meta": {
        "os": "Linux",
        "preinstalled": "NA",
        "flavor": "m7i.4xlarge",
        "cloud_console_link": "https://console.aws.amazon.com/ec2/v2/home?region=ap-south-1#InstanceDetails:instanceId=i-0fbe5281266b3022c",
        "stopped_allocated": False,
        "last_seen_not_stopped": 1752224434,
        "spotted": False,
        "security_groups": [
            "sg-0ded4148f31e4224f",
            "sg-0a4b5ac08bf8f4708"
        ],
        "image_id": "ami-0798aa8605bf303bf",
        "vpc_id": "vpc-090450bfdcbe7972b",
        "vpc_name": "cloudtuner-vpc"
    },
    "name": "cloud-tuner-1",
    "pool_id": "6e57e642-0c77-4829-940e-36dc692255c2",
    "region": "ap-south-1",
    "resource_type": "Instance",
    "service_name": "AmazonEC2",
    "tags": {
        "aws:autoscaling:groupName": "eks-CT-AMD-m7i4xlarge-1-b6cad1b4-33a4-e672-11f4-76dabfe7214b",
        "k8s.io/cluster-autoscaler/finops-cluster": "owned",
        "eks:cluster-name": "finops-cluster",
        "eks:nodegroup-name": "CT-AMD-m7i4xlarge-1",
        "kubernetes.io/cluster/finops-cluster": "owned",
        "aws:ec2:fleet-id": "fleet-968ee4a4-9a9d-c914-8690-0c805f603bbc",
        "aws:eks:cluster-name": "finops-cluster",
        "k8s.io/cluster-autoscaler/enabled": "true",
        "aws:ec2launchtemplate:version": "1",
        "aws:ec2launchtemplate:id": "lt-04fcc0253d9484bd0"
    },
    "last_expense": {
        "date": 1752105600,
        "cost": 11.9989788641
    },
    "total_cost": 2352.2891314211997,
    "active": True,
    "cloud_created_at": 1742203327,
    "recommendations": {
        "run_timestamp": 1752213740,
        "modules": [
            {
                "cloud_resource_id": "i-0fbe5281266b3022c",
                "resource_name": "cloud-tuner-1",
                "cloud_account_id": "9d3a6221-2d42-40ba-8aad-1f50c0cb4bdf",
                "resource_id": "a11f22d7-01f1-4844-94c9-c4fb7d79d5e3",
                "cloud_type": "aws_cnr",
                "cloud_account_name": "API-KYC",
                "security_group_name": "eks-cluster-sg-finops-cluster-1593188108",
                "security_group_id": "sg-0ded4148f31e4224f",
                "region": "ap-south-1",
                "is_excluded": False,
                "insecure_ports": [
                    {
                        "port": "*",
                        "protocol": "*"
                    }
                ],
                "detected_at": 1747388075,
                "name": "insecure_security_groups"
            },
            {
                "saving": 175.43133333333338,
        },
        {
            "date": 1751997600,
            "value": 168979.18229166666
        },
        {
            "date": 1752008400,
            "value": 168768.046875
        },
        {
            "date": 1752019200,
            "value": 169027.90494791666
        },
        {
            "date": 1752030000,
            "value": 169670.39453125
        },
        {
            "date": 1752040800,
            "value": 184503.8046875
        },
        {
            "date": 1752051600,
            "value": 194257.72265625
        },
        {
            "date": 1752062400,
            "value": 183802.11458333334
        },
        {
            "date": 1752073200,
            "value": 174238.38020833334
        },
        {
            "date": 1752084000,
            "value": 169339.83463541666
        },
        {
            "date": 1752094800,
            "value": 175829.7265625
        },
        {
            "date": 1752105600,
            "value": 169399.359375
        },
        {
            "date": 1752116400,
            "value": 169906.34895833334
        },
        {
            "date": 1752127200,
            "value": 170878.34244791666
        },
        {
            "date": 1752138000,
            "value": 178104.22526041666
        },
        {
            "date": 1752148800,
            "value": 174286.99348958334
        },
        {
            "date": 1752159600,
            "value": 172959.21354166666
        },
        {
            "date": 1752170400,
            "value": 170121.36979166666
        },
        {
            "date": 1752181200,
            "value": 169681.46223958334
        },
        {
            "date": 1752192000,
            "value": 169876.73567708334
        },
        {
            "date": 1752202800,
            "value": 170299.11197916666
        },
        {
            "date": 1752213600,
            "value": 177409.29166666666
        },
        {
            "date": 1752224400,
            "value": 213224.615625
        }
    ]
}

# %%
def transform_data(data: dict) -> dict:
    """
    Transforms a raw cloud resource JSON into the simplified schema.
    """
    output = {
        "cloud_resource_id": data.get("cloud_resource_id"),
        "name": data.get("name"),
        "active": data.get("active"),
        "service_name": data.get("service_name"),
        "resource_type": data.get("resource_type"),
        "region": data.get("region"),
        "meta": {
            "flavor": data.get("meta", {}).get("flavor"),
            "vpc_id": data.get("meta", {}).get("vpc_id"),
            "vpc_name": data.get("meta", {}).get("vpc_name"),
            "security_groups": data.get("meta", {}).get("security_groups", [])
        },
        "total_cost": data.get("total_cost"),
        "last_expense": {
            "cost": data.get("last_expense", {}).get("cost"),
            "date": data.get("last_expense", {}).get("date")
        },
        "recommendations": {},
        "tags": data.get("tags", {}),
        "cloud_account_id": data.get("cloud_account_id"),
        "pool_id": data.get("pool_id"),
        "details": {
            "pool_name": data.get("details", {}).get("pool_name"),
            "cost": data.get("details", {}).get("cost"),
            "pool_purpose": data.get("details", {}).get("pool_purpose"),
            "forecast": data.get("details", {}).get("forecast"),
            "total_traffic_expenses": data.get("details", {}).get("total_traffic_expenses"),
            "total_traffic_usage": data.get("details", {}).get("total_traffic_usage")
        },
        "employee_id": data.get("employee_id"),
        "owner_name": data.get("details", {}).get("owner_name"),
        "first_seen": data.get("first_seen"),
        "last_seen": data.get("last_seen"),
        "cloud_created_at": data.get("cloud_created_at"),
        "meta_os": data.get("meta", {}).get("os"),
        "meta_image_id": data.get("meta", {}).get("image_id"),
        "meta_spotted": data.get("meta", {}).get("spotted"),
        "has_metrics": data.get("has_metrics"),
        "applied_rules": data.get("applied_rules")
    }

    for module in data.get("recommendations", {}).get("modules", []):
        name = module.get("name")
        if name == "insecure_security_groups":
            output["recommendations"]["insecure_security_groups"] = {
                "security_group_id": module.get("security_group_id"),
                "security_group_name": module.get("security_group_name"),
                "insecure_ports": module.get("insecure_ports", [])
            }
        elif name == "instances_for_shutdown":
            output["recommendations"]["instances_for_shutdown"] = {
                "inactivity_periods": module.get("inactivity_periods"),
                "saving": module.get("saving")
            }

    return output

# %%
def structure_metrics(raw: Dict[str, Any]) -> Dict[str, Any]:
   
    # Build lookup tables
    cpu_map    = {d["date"]: d["value"] for d in raw["cpu"]}
    in_map     = {d["date"]: d["value"] for d in raw["network_in_io"]}
    out_map    = {d["date"]: d["value"] for d in raw["network_out_io"]}
    
    # Assemble unified list
    metrics = []
    for ts in sorted(cpu_map):
        metrics.append({
            "timestamp": datetime.fromtimestamp(ts, UTC).isoformat() + "Z",
            "cpu":           cpu_map[ts],
            "network_in_io": in_map[ts],
            "network_out_io": out_map[ts],
        })
    
    return {"metrics": metrics}

# %%
def structured_data (transformed_data: Dict[str, Any], transform_monitoring: Dict[str, Any]):
    items = list(transformed_data.items())
    idx = next(
        i for i, (k, _) in enumerate(items)
        if k == "applied_rules"
    )
    items.insert(
        idx + 1,
        ("metrics", transform_monitoring["metrics"])
    )
    return dict(items)

# %%
transformed_data = transform_data(resourceJsonString)
transform_monitoring = structure_metrics(monitoringJsonString)
content = structured_data(transformed_data, transform_monitoring)

# %%
print(transformed_data)
# Out:
# {'cloud_resource_id': 'i-0fbe5281266b3022c', 'name': 'cloud-tuner-1', 'active': True, 'service_name': 'AmazonEC2', 'resource_type': 'Instance', 'region': 'ap-south-1', 'meta': {'flavor': 'm7i.4xlarge', 'vpc_id': 'vpc-090450bfdcbe7972b', 'vpc_name': 'cloudtuner-vpc', 'security_groups': ['sg-0ded4148f31e4224f', 'sg-0a4b5ac08bf8f4708']}, 'total_cost': 2352.2891314211997, 'last_expense': {'cost': 11.9989788641, 'date': 1752105600}, 'recommendations': {'insecure_security_groups': {'security_group_id': 'sg-0ded4148f31e4224f', 'security_group_name': 'eks-cluster-sg-finops-cluster-1593188108', 'insecure_ports': [{'port': '*', 'protocol': '*'}]}}, 'tags': {'aws:autoscaling:groupName': 'eks-CT-AMD-m7i4xlarge-1-b6cad1b4-33a4-e672-11f4-76dabfe7214b', 'k8s.io/cluster-autoscaler/finops-cluster': 'owned', 'eks:cluster-name': 'finops-cluster', 'eks:nodegroup-name': 'CT-AMD-m7i4xlarge-1', 'kubernetes.io/cluster/finops-cluster': 'owned', 'aws:ec2:fleet-id': 'fleet-968ee4a4-9a9d-c914-8690-0c805f603bbc'
# ...

# %%
with open("Checklist_Automation.txt", "r") as file:
    prompt_content = file.read()

prompt = prompt_content
system_prompt = f"""Role: system
            Instruction:
            {prompt}
            Acknowledge and follow this behavior in all responses.
            """

# %% [markdown]
# #Resource

# %%
url = 'http://localhost:11434/api/generate'

data = {
    "model": "gemma3n:e4b",
    "prompt": f"""{transformed_data}\n{system_prompt}""",
    "stream": False
}

# %%
headers = {'Content-Type': 'application/json'}

response = requests.post(url, headers=headers, json=data)
print(response.text)
# Out:
# {"model":"gemma3n:e4b","created_at":"2025-07-11T12:24:04.713305104Z","response":"Data are not exist","done":true,"done_reason":"stop","context":[105,2364,107,64735,12138,236779,500,74964,1916,236744,236779,547,2632,756,236747,236772,236771,30015,236744,236810,236778,236828,236770,236778,236825,236825,236763,236800,236771,236778,236778,236755,963,756,1201,2632,756,12138,236772,110964,236750,236772,236770,963,756,5034,2632,6288,236764,756,8114,236779,1201,2632,756,39460,5856,236778,963,756,500,74964,1916,236744,236779,2084,2632,756,8431,963,756,236750,65186,498,2632,756,670,236772,45071,236772,236770,963,756,7655,2632,16923,191687,2632,756,236757,236832,236747,236761,236812,18765,1997,963,756,160694,236779,547,2632,756,160694,236772,236771,236819,236771,236812,236810,236771,7589,22439,1553,236832,236819,236832,236778,236763,963,756,160694,236779,1201,2632,756,12138,110964,236750,236772,160694,963,756,236751,35056,236750,665,236779,19243,2632,7756,6707,236772,236771,7156,236812,236770,2
# ...

# %%
response_data = response.json()
res_content = response_data.get('response', {})
print("Response Content:", res_content)
# Out:
# Response Content: Data are not exist

# %% [markdown]
# # Meta Data

# %%
metadata = {
    "model": response_data.get('model', ''),
    "created_at": response_data.get('created_at', ''),
    "done_reason": response_data.get('done_reason', ''),
    "done": response_data.get('done', False),
    "total_duration": response_data.get('total_duration', 0) / 1000000000,
    "load_duration": response_data.get('load_duration', 0) / 1000000000,
    "prompt_eval_count": response_data.get('prompt_eval_count', 0),
    "prompt_eval_duration": response_data.get('prompt_eval_duration', 0) / 1000000000,
    "eval_count": response_data.get('eval_count', 0),
    "eval_duration": response_data.get('eval_duration', 0) / 1000000000
}

# %%
print(metadata)
# Out:
# {'model': 'gemma3n:e4b', 'created_at': '2025-07-11T11:13:58.496362447Z', 'done_reason': 'stop', 'done': True, 'total_duration': 5.16940471, 'load_duration': 0.04151543, 'prompt_eval_count': 1533, 'prompt_eval_duration': 0.590686804, 'eval_count': 298, 'eval_duration': 4.53679417}

# %%
json_str1 = '''
[
  {
    "type": "heading",
    "title": "Cost Controls"
  },
  {
    "type": "text",
    "content": "Actions to monitor and manage resource spend."
  },
  {
    "type": "checklist",
    "items": [
      {
        "label": "Analyze Total Expenses of $2352.29: Conduct a detailed review of total expenditure to ensure it aligns with the allocated budget, identifying any deviations that could impact cost efficiency.",
        "checke": false
      },
      {
        "label": "Evaluate Last Date Spend of $11.99: Assess any unanticipated spending fluctuations to identify potential areas for optimization, ensuring alignment with expected resource usage.",
        "checke": false
      },
      {
        "label": "Investigate Cost Anomalies of $7.82: Examine irregularities in network traffic-related expenses, and implement strategies to optimize data transfer, minimizing unnecessary costs.",
        "checke": false
      },
      {
        "label": "Monitor Current Month Spend of $197.26: Conduct a comparative analysis of current month expenses against the designated budget, ensuring that costs remain within planned parameters.",
        "checke": false
      }
    ]
  }
]
'''

# %%
json_str2 = '''
[
  {
    "type": "heading",
    "title": "Resource Overview"
  },
  {
    "type": "text",
    "content": "Key identifiers for this resource."
  },
  {
    "type": "info",
    "items": [
      {
        "label": "Resource ID",
        "value": "i-0fbe5281266b3022c"
      },
      {
        "label": "Name",
        "value": "cloud-tuner-1"
      },
      {
        "label": "Resource Type",
        "value": "Instance"
      },
      {
        "label": "Region",
        "value": "ap-south-1"
      },
      {
        "label": "Owner",
        "value": "Balaji Rao"
      }
    ]
  }
]
'''

# %%
json_str3 = '''
[
  {
    "type": "heading",
    "title": "Usage & Forecast"
  },
  {
    "type": "text",
    "content": "Insights into utilization trends and projected costs."
  },
  {
    "type": "checklist",
    "items": [
      {
        "label": "Monitor total traffic usage of 370.51572771099995 and identify idle resources.",
        "checke": false
      },
      {
        "label": "Analyze network expenses of 7.819887335300001 for possible optimization.",
        "checke": false
      },
      {
        "label": "Review forecasted cost of 622.52 to plan budgeting.",
        "checke": false
      }
    ]
  }
]
'''

# %%
json_str4 = '''
[
  {
    "type": "heading",
    "title": "Security Improvements"
  },
  {
    "type": "text",
    "content": "Measures to enforce least privilege and compliance."
  },
  {
    "type": "checklist",
    "items": [
      {
        "label": "Close port \u20b4/ protocol in security group eks-cluster-sg-finops-cluster-1593188108 to enforce least privilege.",
        "checke": false
      }
    ]
  }
]
'''

# %%
json_str5 = '''
[
  {
    "type": "heading",
    "title": "Security Improvements"
  },
  {
    "type": "text",
    "content": "Measures to enforce least privilege and compliance."
  },
  {
    "type": "checklist",
    "items": [
      {
        "label": "Close port \u20b4/ protocol in security group eks-cluster-sg-finops-cluster-1593188108 to enforce least privilege.",
        "checke": false
      }
    ]
  }
]
'''

# %%
json_str6 = '''
[
  {
    "type": "heading",
    "title": "Applied Rules",
    "colapsible": true
  },
  {
    "type": "text",
    "content": "Governance policies applied to this resource."
  },
  {
    "type": "checklist",
    "items": [
      {
        "label": "Apply policy Rule for API-KYC_1747387550 (ID: 8aebbe1b-6b62-41ab-a33d-2bba0d763cba) to maintain compliance.",
        "checked": false
      }
    ]
  }
]
'''

# %%
json_str7 = '''
[
  {
    "type": "heading",
    "title": "Metadata & Tags",
    "colapsible": true
  },
  {
    "type": "text",
    "content": "Contextual metadata and review tags for accuracy."
  },
  {
    "type": "info",
    "items": [
      { "label": "flavor", "value": "m7i.4xlarge" },
      { "label": "vpc_id", "value": "vpc-090450bfdcbe7972b" },
      { "label": "vpc_name", "value": "cloudtuner-vpc" },
      { "label": "security_groups", "value": "sg-0ded4148f31e4224f, sg-0a4b5ac08bf8f4708" },
      { "label": "aws:autoscaling:groupName", "value": "eks-CT-AMD-m7i4xlarge-1-b6cad1b4-33a4-e672-11f4-76dabfe7214b" },
      { "label": "k8s.io/cluster-autoscaler/finops-cluster", "value": "owned" },
      { "label": "eks:cluster-name", "value": "finops-cluster" },
      { "label": "eks:nodegroup-name", "value": "CT-AMD-m7i4xlarge-1" },
      { "label": "kubernetes.io/cluster/finops-cluster", "value": "owned" },
      { "label": "aws:ec2:fleet-id", "value": "fleet-968ee4a4-9a9d-c914-8690-0c805f603bbc" },
      { "label": "aws:eks:cluster-name", "value": "finops-cluster" },
      { "label": "k8s.io/cluster-autoscaler/enabled", "value": "true" },
      { "label": "aws:ec2launchtemplate:version", "value": "1" },
      { "label": "aws:ec2launchtemplate:id", "value": "lt-04fcc0253d9484bd0" }
    ]
  },
  {
    "type": "checklist",
    "items": [
      { "label": "Review tag aws:autoScaling:groupName: eks-CT-AMD-m7i4xlarge-1-b6cad1b4-33a4-e672-11f4-76dabfe7214b for accuracy.", "checkeed": false },
      { "label": "Review tag k8s.io/cluster-autoscaler/finops-cluster: owned for accuracy.", "checkeed": false },
      { "label": "Review tag eks:cluster-name: finops-cluster for accuracy.", "checkeed": false },
      { "label": "Review tag eks:nodegroup-name: CT-AMD-m7i4xlarge-1 for accuracy.", "checkeed": false },
      { "label": "Review tag kubernetes.io/cluster/finops-cluster: owned for accuracy.", "checkeed": false },
      { "label": "Review tag aws:ec2:fleet-id: fleet-968ee4a4-9a9d-c914-8690-0c805f603bbc for accuracy.", "checkeed": false },
      { "label": "Review tag aws:eks:cluster-name: finops-cluster for accuracy.", "checkeed": false },
      { "label": "Review tag k8s.io/cluster-autoscaler/enabled: true for accuracy.", "checkeed": false },
      { "label": "Review tag aws:ec2launchtemplate:version: 1 for accuracy.", "checkeed": false },
      { "label": "Review tag aws:ec2launchtemplate:id: lt-04fcc0253d9484bd0 for accuracy.", "checkeed": false }
    ]
  }
]
'''

# %%
def merge_json_inputs(*inputs: Union[str, Any]) -> List[Any]:
    merged = []
    for inp in inputs:
        # parse strings
        if isinstance(inp, str):
            try:
                data = json.loads(inp)
            except json.JSONDecodeError:
                data = ast.literal_eval(inp)
        else:
            data = inp

        # normalize checklist keys
        if isinstance(data, list):
            for section in data:
                if section.get("type") == "checklist" and isinstance(section.get("items"), list):
                    for item in section["items"]:
                        # rename any misspelled key to `checked`
                        for bad in ("checke", "checkeed"):
                            if bad in item:
                                item["checked"] = item.pop(bad)
            merged.extend(data)
        else:
            merged.append(data)

    return merged

# %%
merged = merge_json_inputs(json_str1, json_str2, json_str3, json_str4, json_str5, json_str6, json_str7)

# %%
print(json.dumps(merged, indent=2))
# Out:
# [
#   {
#     "type": "heading",
#     "title": "Cost Controls"
#   },
#   {
#     "type": "text",
#     "content": "Actions to monitor and manage resource spend."
#   },
#   {
#     "type": "checklist",
#     "items": [
#       {
#         "label": "Analyze Total Expenses of $2352.29: Conduct a detailed review of total expenditure to ensure it aligns with the allocated budget, identifying any deviations that could impact cost efficiency.",
#         "checked": false
#       },
#       {
#         "label": "Evaluate Last Date Spend of $11.99: Assess any unanticipated spending fluctuations to identify potential areas for optimization, ensuring alignment with expected resource usage.",
#         "checked": false
#       },
#       {
#         "label": "Investigate Cost Anomalies of $7.82: Examine irregularities in network traffic-related expenses, and implement strategies to optimize data transfer, minimizing unnecessary costs.",
#         "checked": false
#       },
#       {
# ...
