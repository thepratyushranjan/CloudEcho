# %%
import os
import json
import requests
from datetime import datetime, UTC
from typing import Any, List, Optional, Dict, Tuple
from itertools import chain
from google import genai
from google.genai import types

# %%
source  = {
"cloud_account_id": "9d3a6221-2d42-40ba-8aad-1f50c0cb4bdf",
"cloud_resource_id": "i-05d745c5c5c70f87b",
"applied_rules": [
{
"id": "8aebbe1b-6b62-41ab-a33d-2bba0d763cba",
"name": "Rule for API-KYC_1747387550",
"pool_id": "6e57e642-0c77-4829-940e-36dc692255c2"
}
],
"created_at": 1747387567,
"deleted_at": 0,
"employee_id": "a1aeb309-c565-4cbd-a25e-8fe25f3328de",
"first_seen": 1743120000,
"last_seen": 1747630800,
"meta": {
"os": "NA",
"preinstalled": "NA",
"flavor": "t3a.xlarge",
"cloud_console_link": "https://console.aws.amazon.com/ec2/v2/home?region=ap-south-1#InstanceDetails:instanceId=i-05d745c5c5c70f87b",
"stopped_allocated": False,
"last_seen_not_stopped": 1747513701,
"spotted": False,
"security_groups": [
"sg-0d3735aac58a722a3"
],
"image_id": "ami-0e35ddab05955cf57",
"vpc_id": "vpc-0f4ac030ab07791b0",
"vpc_name": "default-vpc-do-not-use"
},
"name": "prod-invincibleocean-web",
"pool_id": "6e57e642-0c77-4829-940e-36dc692255c2",
"region": "ap-south-1",
"resource_type": "Instance",
"service_name": "AmazonEC2",
"tags": {},
"last_expense": {
"date": 1747612800,
"cost": 0.4909759282
},
"total_cost": 122.51240631310002,
"active": True,
"cloud_created_at": 1743140274,
"recommendations": {
"run_timestamp": 1747647275,
"modules": [
{
"cloud_resource_id": "i-05d745c5c5c70f87b",
"resource_name": "prod-invincibleocean-web",
"cloud_account_id": "9d3a6221-2d42-40ba-8aad-1f50c0cb4bdf",
"resource_id": "f1baa4b6-ff36-48b2-ab7c-ae06a5c3bbfa",
"cloud_type": "aws_cnr",
"cloud_account_name": "API-KYC",
"security_group_name": "launch-wizard-10",
"security_group_id": "sg-0d3735aac58a722a3",
"region": "ap-south-1",
"is_excluded": True,
"insecure_ports": [
{
"port": 22,
"protocol": "tcp"
}
],
"detected_at": 1747388075,
"name": "insecure_security_groups"
},
{
"resource_id": "f1baa4b6-ff36-48b2-ab7c-ae06a5c3bbfa",
"resource_name": "prod-invincibleocean-web",
"cloud_resource_id": "i-05d745c5c5c70f87b",
"region": "ap-south-1",
"cloud_account_id": "9d3a6221-2d42-40ba-8aad-1f50c0cb4bdf",
"cloud_type": "aws_cnr",
"cloud_account_name": "API-KYC",
"owner": {
"id": "a1aeb309-c565-4cbd-a25e-8fe25f3328de",
"name": "Balaji Rao"
},
"pool": {
"id": "6e57e642-0c77-4829-940e-36dc692255c2",
"name": "API-KYC",
"purpose": "budget"
},
"is_excluded": False,
"inactivity_periods": [
{
"start": {
"day_of_week": 0,
"hour": 0
},
"end": {
"day_of_week": 0,
"hour": 3
}
},
{
"start": {
"day_of_week": 0,
"hour": 10
},
"end": {
"day_of_week": 1,
"hour": 1
}
},
{
"start": {
"day_of_week": 1,
"hour": 3
},
"end": {
"day_of_week": 1,
"hour": 3
}
},
{
"start": {
"day_of_week": 1,
"hour": 6
},
"end": {
"day_of_week": 1,
"hour": 8
}
},
{
"start": {
"day_of_week": 1,
"hour": 10
},
"end": {
"day_of_week": 1,
"hour": 11
}
},
{
"start": {
"day_of_week": 1,
"hour": 13
},
"end": {
"day_of_week": 1,
"hour": 16
}
},
{
"start": {
"day_of_week": 1,
"hour": 18
},
"end": {
"day_of_week": 2,
"hour": 2
}
},
{
"start": {
"day_of_week": 2,
"hour": 8
},
"end": {
"day_of_week": 2,
"hour": 9
}
},
{
"start": {
"day_of_week": 2,
"hour": 11
},
"end": {
"day_of_week": 2,
"hour": 11
}
},
{
"start": {
"day_of_week": 2,
"hour": 13
},
"end": {
"day_of_week": 3,
"hour": 3
}
},
{
"start": {
"day_of_week": 3,
"hour": 9
},
"end": {
"day_of_week": 3,
"hour": 9
}
},
{
"start": {
"day_of_week": 3,
"hour": 11
},
"end": {
"day_of_week": 3,
"hour": 15
}
},
{
"start": {
"day_of_week": 3,
"hour": 17
},
"end": {
"day_of_week": 4,
"hour": 3
}
},
{
"start": {
"day_of_week": 4,
"hour": 7
},
"end": {
"day_of_week": 4,
"hour": 15
}
},
{
"start": {
"day_of_week": 4,
"hour": 18
},
"end": {
"day_of_week": 5,
"hour": 3
}
},
{
"start": {
"day_of_week": 5,
"hour": 5
},
"end": {
"day_of_week": 5,
"hour": 23
}
},
{
"start": {
"day_of_week": 6,
"hour": 2
},
"end": {
"day_of_week": 6,
"hour": 23
}
}
],
"saving": 56.630719314045905,
"detected_at": 1747399175,
"name": "instances_for_shutdown"
}
]
},
"has_metrics": True,
"id": "f1baa4b6-ff36-48b2-ab7c-ae06a5c3bbfa",
"sub_resources": [],
"is_environment": False,
"env_properties": {},
"dismissed_recommendations": {},
"dismissed": [],
"details": {
"cloud_type": "aws_cnr",
"cloud_name": "API-KYC",
"total_cost": 122.51240631310002,
"cost": 43.0901305846,
"forecast": 73.88,
"service_name": "AmazonEC2",
"region": "ap-south-1",
"pool_name": "API-KYC",
"pool_purpose": "budget",
"owner_name": "Balaji Rao",
"last_seen": 1747630800,
"first_seen": 1743120000,
"active": True,
"policies": {},
"constraints": {},
"shareable_bookings": [],
"env_properties_collector_link": None,
"total_traffic_expenses": 0.0146083958,
"total_traffic_usage": 0.7954606422000009
}
}

# %%
monitoring = {
    "cpu": [
        {
            "date": 1746079200,
            "value": 0.24791468431552252
        },
        {
            "date": 1746100800,
            "value": 0.23217680429418883
        },
        {
            "date": 1746122400,
            "value": 0.23793630177776018
        },
        {
            "date": 1746144000,
            "value": 0.2131508787473043
        },
        {
            "date": 1746165600,
            "value": 0.2437677023311456
        },
        {
            "date": 1746187200,
            "value": 0.22225561179220676
        },
        {
            "date": 1746208800,
        },
        {
            "date": 1747180800,
            "value": 66.23851919174194
        },
        {
            "date": 1747202400,
            "value": 5294.252743721008
        },
        {
            "date": 1747224000,
            "value": 1197.1119741598766
        },
        {
            "date": 1747245600,
            "value": 294.44759090741474
        },
        {
            "date": 1747267200,
            "value": 232.0353323618571
        },
        {
            "date": 1747288800,
            "value": 2426.431831677755
        },
        {
            "date": 1747310400,
            "value": 1046.3823048273723
        },
        {
            "date": 1747332000,
            "value": 169.7433819770813
        },
        {
            "date": 1747353600,
            "value": 214.67291450500488
        },
        {
            "date": 1747375200,
            "value": 167.2187034289042
        },
        {
            "date": 1747396800,
            "value": 148.03291622797647
        },
        {
            "date": 1747418400,
            "value": 180.7862958908081
        },
        {
            "date": 1747440000,
            "value": 79.58245396614075
        },
        {
            "date": 1747461600,
            "value": 1295.5997554461162
        },
        {
            "date": 1747483200,
            "value": 145.83370288213095
        },
        {
            "date": 1747504800,
            "value": 74.74879638353984
        },
        {
            "date": 1747526400,
            "value": 85.30648152033488
        },
        {
            "date": 1747548000,
            "value": 56.62527743975321
        },
        {
            "date": 1747569600,
            "value": 86.33296243349712
        },
        {
            "date": 1747591200,
            "value": 42.52874986330668
        },
        {
            "date": 1747612800,
            "value": 137.95749974250793
        },
        {
            "date": 1747634400,
            "value": 1250.2344774405162
        },
        {
            "date": 1747656000,
            "value": 1145.8701867323655
        }
    ]
}

# %%
def transform_data(data: dict) -> dict:
    """
    Transforms a raw cloud resource JSON into the simplified schema.
    """
    output = {
        "cloud_resource_id": data.get("cloud_resource_id"),
        "name": data.get("name"),
        "active": data.get("active"),
        "service_name": data.get("service_name"),
        "resource_type": data.get("resource_type"),
        "region": data.get("region"),
        "meta": {
            "flavor": data.get("meta", {}).get("flavor"),
            "vpc_id": data.get("meta", {}).get("vpc_id"),
            "vpc_name": data.get("meta", {}).get("vpc_name"),
            "security_groups": data.get("meta", {}).get("security_groups", [])
        },
        "total_cost": data.get("total_cost"),
        "last_expense": {
            "cost": data.get("last_expense", {}).get("cost"),
            "date": data.get("last_expense", {}).get("date")
        },
        "recommendations": {},
        "tags": data.get("tags", {}),
        "cloud_account_id": data.get("cloud_account_id"),
        "pool_id": data.get("pool_id"),
        "details": {
            "pool_name": data.get("details", {}).get("pool_name"),
            "pool_purpose": data.get("details", {}).get("pool_purpose"),
            "forecast": data.get("details", {}).get("forecast"),
            "total_traffic_expenses": data.get("details", {}).get("total_traffic_expenses"),
            "total_traffic_usage": data.get("details", {}).get("total_traffic_usage")
        },
        "employee_id": data.get("employee_id"),
        "owner_name": data.get("details", {}).get("owner_name"),
        "first_seen": data.get("first_seen"),
        "last_seen": data.get("last_seen"),
        "cloud_created_at": data.get("cloud_created_at"),
        "meta_os": data.get("meta", {}).get("os"),
        "meta_image_id": data.get("meta", {}).get("image_id"),
        "meta_spotted": data.get("meta", {}).get("spotted"),
        "has_metrics": data.get("has_metrics"),
        "applied_rules": data.get("applied_rules")
    }

    for module in data.get("recommendations", {}).get("modules", []):
        name = module.get("name")
        if name == "insecure_security_groups":
            output["recommendations"]["insecure_security_groups"] = {
                "security_group_id": module.get("security_group_id"),
                "security_group_name": module.get("security_group_name"),
                "insecure_ports": module.get("insecure_ports", [])
            }
        elif name == "instances_for_shutdown":
            output["recommendations"]["instances_for_shutdown"] = {
                "inactivity_periods": module.get("inactivity_periods"),
                "saving": module.get("saving")
            }

    return output

# %%
def structure_metrics(raw: Dict[str, Any]) -> Dict[str, Any]:

    # Build lookup tables
    cpu_map    = {d["date"]: d["value"] for d in raw["cpu"]}
    in_map     = {d["date"]: d["value"] for d in raw["network_in_io"]}
    out_map    = {d["date"]: d["value"] for d in raw["network_out_io"]}

    # Assemble unified list
    metrics = []
    for ts in sorted(cpu_map):
        metrics.append({
            "timestamp": datetime.fromtimestamp(ts, UTC).isoformat() + "Z",
            "cpu":           cpu_map[ts],
            "network_in_io": in_map[ts],
            "network_out_io": out_map[ts],
        })
    print({"metrics": metrics})
    return {"metrics": metrics}

# %%
def structured_data (content: Dict[str, Any], monitoring: Dict[str, Any]):
    items = list(content.items())
    idx = next(
        i for i, (k, _) in enumerate(items)
        if k == "applied_rules"
    )
    items.insert(
        idx + 1,
        ("metrics", monitoring["metrics"])
    )

    return dict(items)

# %%
transform_monitoring = structure_metrics(monitoring)
transform_sources = transform_data(source)
content = structured_data(transform_sources, transform_monitoring)
# Out:
# {'metrics': [{'timestamp': '2025-05-01T06:00:00+00:00Z', 'cpu': 0.24791468431552252, 'network_in_io': 163.44032621383667, 'network_out_io': 2535.752167701721}, {'timestamp': '2025-05-01T12:00:00+00:00Z', 'cpu': 0.23217680429418883, 'network_in_io': 6621.598295211792, 'network_out_io': 130.90027809143066}, {'timestamp': '2025-05-01T18:00:00+00:00Z', 'cpu': 0.23793630177776018, 'network_in_io': 398.79385169347125, 'network_out_io': 109.76194429397583}, {'timestamp': '2025-05-02T00:00:00+00:00Z', 'cpu': 0.2131508787473043, 'network_in_io': 71.91143496831258, 'network_out_io': 647.4589703877767}, {'timestamp': '2025-05-02T06:00:00+00:00Z', 'cpu': 0.2437677023311456, 'network_in_io': 349.9342498779297, 'network_out_io': 1191.0315084457397}, {'timestamp': '2025-05-02T12:00:00+00:00Z', 'cpu': 0.22225561179220676, 'network_in_io': 72.59939845403035, 'network_out_io': 324.70402987798053}, {'timestamp': '2025-05-02T18:00:00+00:00Z', 'cpu': 0.24746918678283691, 'network_in_io': 222.311015129089
# ...

# %%
def extract_basic_info(data: dict) -> dict:

    return {
        "cloud_resource_id": data.get("cloud_resource_id"),
        "name":               data.get("name"),
        "service_name":       data.get("service_name"),
        "resource_type":      data.get("resource_type"),
        "region":             data.get("region"),
        "flavor":             data.get("meta", {}).get("flavor"),
    }

# %%
basic_info = extract_basic_info(source)

# %%
print(basic_info)
# Out:
# {'cloud_resource_id': 'i-05d745c5c5c70f87b', 'name': 'prod-invincibleocean-web', 'service_name': 'AmazonEC2', 'resource_type': 'Instance', 'region': 'ap-south-1', 'flavor': 't3a.xlarge'}

# %%
def get_cloud_comparison(basic_info):
    region = basic_info.get("region")
    flavor = basic_info.get("flavor")

    payload = {
        "location":          [],
        "instance_families": [],
        "clouds":           ["AWS"],
        "instance_type":    [flavor] if flavor else [],
        "regions":          [region] if region else [] 
    }

    url = "http://localhost:8069/chat-agent/cloud-comparison/cloud-provider"
    headers = {"Content-Type": "application/json"}
    try:
        resp = requests.post(url, json=payload, headers=headers, timeout=10)
        resp.raise_for_status()
        return resp.json()
    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}")
    except ValueError:
        print("Response wasn’t valid JSON:", resp.text)
    return None

comparison = get_cloud_comparison(basic_info)
print(comparison)
# Out:
# {'cloud_multiple_data': [{'id': 535, 'region': 'ap-south-1', 'location': 'Asia Pacific (Mumbai)', 'instance_type': 't3a.xlarge', 'instance_family': 'General Purpose', 'vcpus': 4, 'ram_gib': 16.0, 'memory_mib': 16384, 'cost_per_hour': 0.0986, 'cloud': 'AWS'}]}

# %%
AWS_REGION_TO_COUNTRY = {
    "us-east-1": "USA",
    "us-east-2": "USA",
    "us-west-1": "USA",
    "us-west-2": "USA",
    "af-south-1": "South Africa",
    "ap-east-1": "Hong Kong",
    "ap-south-2": "India",
    "ap-southeast-3": "Indonesia",
    "ap-southeast-5": "Malaysia",
    "ap-southeast-4": "Australia",
    "ap-south-1": "India",
    "ap-northeast-3": "Japan",
    "ap-northeast-2": "South Korea",
    "ap-southeast-1": "Singapore",
    "ap-southeast-2": "Australia",
    "ap-east-2": "Taiwan",
    "ap-southeast-7": "Thailand",
    "ap-northeast-1": "Japan",
    "ca-central-1": "Canada",
    "ca-west-1": "Canada",
    "eu-central-1": "Germany",
    "eu-west-1": "Ireland",
    "eu-west-2": "United Kingdom",
    "eu-south-1": "Italy",
    "eu-west-3": "France",
    "eu-south-2": "Spain",
    "eu-north-1": "Sweden",
    "eu-central-2": "Switzerland",
    "il-central-1": "Israel",
    "mx-central-1": "Mexico",
    "me-south-1": "Bahrain",
    "me-central-1": "United Arab Emirates",
    "sa-east-1": "Brazil",
    "us-gov-east-1": "USA",
    "us-gov-west-1": "USA"
}

# %%
def get_country_from_aws_region_code(region_code: str) -> Optional[str]:
    return AWS_REGION_TO_COUNTRY.get(region_code)

country = get_country_from_aws_region_code(basic_info.get("region"))
print(country)  # Output: USA
# Out:
# India

# %%
def get_cloud_comparison_filter(comparison):

    data_list = comparison.get("cloud_multiple_data", [])
    if not data_list:
        return None
    vcpus = list({item.get("vcpus") for item in data_list if item.get("vcpus") is not None})
    ram_gib = list({item.get("ram_gib") for item in data_list if item.get("ram_gib") is not None})
    memory_mib = list({item.get("memory_mib") for item in data_list if item.get("memory_mib") is not None})
    cost_per_hour = list({item.get("cost_per_hour") for item in data_list if item.get("cost_per_hour") is not None})
    instance_families = list({item.get("instance_family") 
                              for item in data_list 
                              if item.get("instance_family")})

   
    payload = {
        "vcpus":           vcpus,
        "ram_gib":         ram_gib,
        "memory_mib":      memory_mib,
        "cost_per_hour":   cost_per_hour,
        "instance_families": instance_families,
        "country":["India"],
    }

  
    url = "http://localhost:8069/chat-agent/cloud-comparison/cloud-provider/filter/"
    headers = {"Content-Type": "application/json"}
    try:
        resp = requests.post(url, json=payload, headers=headers, timeout=10)
        resp.raise_for_status()
        return resp.json()
    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}")
    except ValueError:
        print("Response wasn’t valid JSON:", resp.text)
    return None

filtered = get_cloud_comparison_filter(comparison)
print(filtered)
# Out:
# {'cloud_multiple_data': [{'id': 385, 'region': 'ap-south-1', 'location': 'Asia Pacific (Mumbai)', 'instance_type': 't4g.xlarge', 'instance_family': 'General Purpose', 'vcpus': 4, 'ram_gib': 16.0, 'memory_mib': 16384, 'cost_per_hour': 0.0896, 'cloud': 'AWS'}, {'id': 535, 'region': 'ap-south-1', 'location': 'Asia Pacific (Mumbai)', 'instance_type': 't3a.xlarge', 'instance_family': 'General Purpose', 'vcpus': 4, 'ram_gib': 16.0, 'memory_mib': 16384, 'cost_per_hour': 0.0986, 'cloud': 'AWS'}, {'id': 23830, 'region': 'CentralIndia', 'location': 'IN Central', 'instance_type': 'Standard_B4as_v2', 'instance_family': 'General Purpose', 'vcpus': 4, 'ram_gib': 16.0, 'memory_mib': 16384, 'cost_per_hour': 0.0467, 'cloud': 'Azure'}, {'id': 23834, 'region': 'CentralIndia', 'location': 'IN Central', 'instance_type': 'Standard_B4ps_v2', 'instance_family': 'General Purpose', 'vcpus': 4, 'ram_gib': 16.0, 'memory_mib': 16384, 'cost_per_hour': 0.0432, 'cloud': 'Azure'}, {'id': 23835, 'region': 'CentralInd
# ...

# %%
def structured_data_with_cloud_migration(
    content: Dict[str, Any],
    monitoring: Dict[str, Any],
    filtered: Dict[str, Any]
) -> Dict[str, Any]:
    items: List[Tuple[str, Any]] = list(content.items())

    idx = next(
        i for i, (k, _) in enumerate(items)
        if k == "applied_rules"
    )
    items.insert(idx + 1, ("metrics", monitoring["metrics"]))
    items.insert(idx + 2, ("comparison", filtered))
    return dict(items)

# %%
final_content = structured_data_with_cloud_migration(transform_sources, transform_monitoring, filtered)
print(final_content)
# Out:
# {'cloud_resource_id': 'i-05d745c5c5c70f87b', 'name': 'prod-invincibleocean-web', 'active': True, 'service_name': 'AmazonEC2', 'resource_type': 'Instance', 'region': 'ap-south-1', 'meta': {'flavor': 't3a.xlarge', 'vpc_id': 'vpc-0f4ac030ab07791b0', 'vpc_name': 'default-vpc-do-not-use', 'security_groups': ['sg-0d3735aac58a722a3']}, 'total_cost': 122.51240631310002, 'last_expense': {'cost': 0.4909759282, 'date': 1747612800}, 'recommendations': {'insecure_security_groups': {'security_group_id': 'sg-0d3735aac58a722a3', 'security_group_name': 'launch-wizard-10', 'insecure_ports': [{'port': 22, 'protocol': 'tcp'}]}, 'instances_for_shutdown': {'inactivity_periods': [{'start': {'day_of_week': 0, 'hour': 0}, 'end': {'day_of_week': 0, 'hour': 3}}, {'start': {'day_of_week': 0, 'hour': 10}, 'end': {'day_of_week': 1, 'hour': 1}}, {'start': {'day_of_week': 1, 'hour': 3}, 'end': {'day_of_week': 1, 'hour': 3}}, {'start': {'day_of_week': 1, 'hour': 6}, 'end': {'day_of_week': 1, 'hour': 8}}, {'start': {
# ...

# %%
query = "Cross‑Cloud Migration"
data = { "content": final_content, "question": query }
final_data = json.dumps(data, indent=2)
print(final_data)

# %%
GEMINI_API_KEY = "AIzaSyBKT6-nzJADAA3sTI7IuwMjjPtqIy5z4TY"
file_path = "../Cloud_Migrations_Prompt.txt"
if not os.path.isfile(file_path):
    raise FileNotFoundError(f"File not found: {file_path}")
with open(file_path, "r", encoding="utf-8") as f:
    prompt = f.read()

# %%
class DetailsLlmGenerator:
    def __init__(self, llm_model_name: str = "gemini-2.0-flash"):
        self.llm_model_name = llm_model_name
        self.client = genai.Client(api_key=GEMINI_API_KEY)
        self.system_instruction = prompt

    def generate_query_response(self, final_data: dict):
        try:
            stream_response = self.client.models.generate_content_stream(
                model=self.llm_model_name,
                config=types.GenerateContentConfig(system_instruction=self.system_instruction),
                contents=final_data,
            )

            response_text = ""
            for chunk in stream_response:
                if hasattr(chunk, "text"):
                    print(chunk.text, end="")
                    response_text += chunk.text
            return response_text
        except Exception as e:
            raise Exception(f"Error generating response for combined prompt: {e}")

    def llm_query(self, final_data: dict) -> str:
        return self.generate_query_response(final_data)

# %%
details_llm_generator = DetailsLlmGenerator()
response = details_llm_generator.llm_query(final_data)
# Out:
# ## 1. Cross-Cloud Migration Overview
#
# * **Resource ID**: `i-05d745c5c5c70f87b`
# * **Name**: `prod-invincibleocean-web`
# * **Current Cloud**: AWS, Region: `ap-south-1`
# * **Current Instance**: `t3a.xlarge` (4 vCPUs, 16 GiB RAM)
# * **Hourly Cost**: \$0.0986
# * **Estimated Monthly Cost**: \$71.978
# * **Latest-Expense:** \$0.4909759282
#
# This report explores migrating `prod-invincibleocean-web` from AWS to Azure to reduce operational costs. The primary criterion is identifying Azure instances with equivalent or superior vCPU and RAM at a lower hourly cost.
#
# ---
#
# ## 2. Strategic Analysis
#
# 1. **Baseline Configuration**
#
#    *   4 vCPUs
#    *   16 GiB RAM
#    *   Located in `ap-south-1` (AWS)
#    *   Hourly Cost: \$0.0986
#
# 2. **Candidate Selection**
#
#    *   **Filter**: Instances with ≥ 4 vCPUs and 16 GiB RAM.
#    *   **Group**: Split into AWS and Azure lists.
#    *   **Rank**: Sort each list by `cost_per_hour` ascending; take top 5 from each.
# ...
